# %%
from grid_generator import *
from wrp_solver import *
from wrp_solver_opt import *
from utils import *
from autoregressive_unet import *
import matplotlib.pyplot as plt
from tqdm import tqdm
from data_generator import *
from inference import *
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import time
import os
import random
# %matplotlib inline
plt.ion()  

# ---------- Global device config ----------
# Set to one of: "auto", "mps", "cuda", "cpu"
DEVICE_PREF = "mps"

def resolve_device(pref=DEVICE_PREF):
    pref = pref.lower()
    if pref == "auto":
        if hasattr(torch.backends, "mps") and torch.backends.mps.is_available():
            return torch.device("mps")
        if torch.cuda.is_available():
            return torch.device("cuda")
        return torch.device("cpu")
    if pref == "mps":
        if hasattr(torch.backends, "mps") and torch.backends.mps.is_available():
            return torch.device("mps")
        print("Warning: MPS requested but not available. Falling back to CPU.")
        return torch.device("cpu")
    if pref == "cuda":
        if torch.cuda.is_available():
            return torch.device("cuda")
        print("Warning: CUDA requested but not available. Falling back to CPU.")
        return torch.device("cpu")
    return torch.device("cpu")

DEVICE = resolve_device()
print(f"Using device: {DEVICE}")
# Out:
# Using device: mps

# %%
# config 
VISION_RADIUS = 8
LOS = 'bresenham'
GRAZING = True

# %%
# Generate a random grid
gen = WRPDataGenerator(16, 16)
grid, start = gen.generate_valid_grid(density=5, clutter_proba=0.55, free_ratio_threshold=0.5)
# grid, start = gen.generate_simple_polygon_grid()
print("Generated Grid:")

plot_grid(grid, start)
# plt.show()
# Out:
# Generated Grid:

# %%
plot_visibility2(grid, path_opt[:28], los_type=LOS, vision_radius=VISION_RADIUS, grazing_walls=GRAZING)
# Out:
# <Axes: >

# %%
X1, y1 = generate_training_data_for_online_learning(grid, path_opt, grazing_walls = GRAZING, discounted_step=10, los_type=LOS, vision_radius=VISION_RADIUS)

# %%
step = 4
fig, axes = plt.subplots(2, 2, figsize=(8, 8))
ax = axes.ravel()

curr_loc_idx = X1[step][1].argmax(axis=None)
curr_loc = np.unravel_index(curr_loc_idx, X1[step][1].shape)

plt.sca(ax[0])
plot_grid(X1[step][2], curr_loc)
ax[0].set_title("Unseen Map", fontsize=10, fontweight="bold")

plt.sca(ax[1])
plot_grid(X1[step][0], curr_loc)
ax[1].set_title("Known Obstacles", fontsize=10, fontweight="bold")



plt.sca(ax[2])
plot_grid(y1[step][0], curr_loc)
ax[2].set_title("Target Heatmap", fontsize=10, fontweight="bold")


plt.sca(ax[3])
plot_path(grid, path_opt, start)
ax[3].set_title("Optimal Offline Path", fontsize=10, fontweight="bold")


plt.tight_layout()
plt.show()

# %%
#filter out data from X_train when unseen cell are less than half of the total cells in the grid   

def filter_samples_from_data(X_train, y_train, no_filtering=True):
    if no_filtering:
        return X_train, y_train  # Return original data without filtering
    filtered_X = []
    filtered_y = []
    
    for i in range(len(X_train)):
        unseen_map = X_train[i][2]  # Assuming the unseen map is at index 2
        H, W = unseen_map.shape[-2], unseen_map.shape[-1]
        total_cells = H * W
        unseen_cells = unseen_map.sum().item()  # Count of unseen cells (assuming unseen cells are marked with 1)
        
        if unseen_cells <= total_cells / 1.5:  # Keep samples where unseen cells are less than or equal to two-thirds of total cells
            filtered_X.append(X_train[i])
            filtered_y.append(y_train[i])
    
    return torch.stack(filtered_X), torch.stack(filtered_y)

# %%
if LOS == 'los4':
    X_train1, y_train1 = load_data_from_disk("data/wrp_online_grazing_data_16x16_1000_samples_SP_train.pt")
    X_train2, y_train2 = load_data_from_disk("data/wrp_online_grazing_data_16x16_1000_samples_SP_train2.pt")
    X_train3, y_train3 = load_data_from_disk("data/wrp_online_grazing_data_16x16_1000_samples_SP_train3.pt")

    X_train_hard, y_train_hard=load_data_from_disk("data/wrp_online_grazing_data_16x16_780_samples_SP_train_hard.pt", sample = 0.5)

    X_test, y_test = load_data_from_disk("data/wrp_online_grazing_data_16x16_750_samples_SP_test.pt")
    
    X_train, y_train = torch.cat([X_train1, X_train_hard, X_train2, X_train3]), torch.cat([y_train1, y_train_hard, y_train2, y_train3])
    print("Final training data shapes:", X_train.shape, y_train.shape)

# %%
def generate_N_training_data_for_online_learning_from_npy_gt(folder_path, discounted_step = 0, grazing_walls=GRAZING, los_type = LOS, vision_radius = VISION_RADIUS, timeout=600, num_samples = None):
    X_list = []
    y_list = []
    skipped = 0
    
    folder_paths = sorted(os.listdir(folder_path))
    total_files_processed = 0
    for i, npyfile in enumerate(tqdm(folder_paths)):
        if (not npyfile.endswith(".npy")): continue
        if num_samples is not None and total_files_processed >= num_samples:
            break

        npyfilePath = os.path.join(folder_path, npyfile)
        gt_data = np.load(npyfilePath, allow_pickle=True).item()
        grid = gt_data["grid"]
        start = gt_data["start"]
        path_subopt = gt_data["path_opt"]
        
        # Generate training data from the path
        X, y = generate_training_data_for_online_learning(grid, path_subopt, discounted_step=discounted_step, grazing_walls=grazing_walls, los_type=los_type, vision_radius=vision_radius)
        X_list.append(torch.tensor(X, dtype=torch.float32))
        y_list.append(torch.tensor(y, dtype=torch.float32))
        total_files_processed += 1
    
    if skipped:
        print(f"Skipped {skipped}/{len(folder_paths)} samples due to timeout ({timeout}s)")
    print(f"Processed {total_files_processed}/{len(folder_paths)} files.")
    return torch.cat(X_list), torch.cat(y_list)

if LOS == 'square360':
    print("Generating training data for Square360 LOS...")
    wrp_X_train, wrp_y_train = generate_N_training_data_for_online_learning_from_npy_gt("data/wrp_online_data_16x16_los_square360_vision_8_5000_samples_train", discounted_step=10, grazing_walls=GRAZING, los_type=LOS, vision_radius=VISION_RADIUS, timeout=600)
    X_test, y_test = generate_N_training_data_for_online_learning_from_npy_gt("data/wrp_online_data_16x16_los_square360_vision_8_700_samples_test", discounted_step=10, grazing_walls=GRAZING, los_type=LOS, vision_radius=VISION_RADIUS, timeout=600)

if LOS == 'bresenham':
    print("Generating training data for Bresenham LOS...")
    wrp_X_train, wrp_y_train = generate_N_training_data_for_online_learning_from_npy_gt("data/wrp_online_data_16x16_los_bresenham_vision_8_5000_samples_train", discounted_step=8, grazing_walls=GRAZING, los_type=LOS, vision_radius=VISION_RADIUS, timeout=600)
    X_test, y_test = generate_N_training_data_for_online_learning_from_npy_gt("data/wrp_online_data_16x16_los_bresenham_vision_8_1000_samples_test", discounted_step=8, grazing_walls=GRAZING, los_type=LOS, vision_radius=VISION_RADIUS, timeout=600)
# Out:
# Generating training data for Bresenham LOS...
# 100%|██████████| 5400/5400 [15:10<00:00,  5.93it/s]
# Processed 5399/5400 files.
# 100%|██████████| 983/983 [02:15<00:00,  7.25it/s]
# Processed 983/983 files.

# %%
total_samples = wrp_X_train.shape[0]
section_size =   total_samples // 2

X_train_f, y_train_f = filter_samples_from_data(wrp_X_train[:section_size], wrp_y_train[:section_size], no_filtering=False)
X_train = torch.cat([X_train_f, wrp_X_train[section_size:]])
y_train = torch.cat([y_train_f, wrp_y_train[section_size:]])

# %%
wrp_X_train.shape
# Out:
# torch.Size([156772, 3, 16, 16])

# %%
X_train.shape
# Out:
# torch.Size([149586, 3, 16, 16])

# %%
ind = 23
fig, axes = plt.subplots(2, 2, figsize=(8, 8))
ax = axes.ravel()

curr_loc_idx = X_train[ind][1].argmax(axis=None)
curr_loc = np.unravel_index(curr_loc_idx, X_train[ind][1].shape)

plt.sca(ax[0])
plot_grid(X_train[ind][0], curr_loc)
ax[0].set_title("Unseen Map", fontsize=10, fontweight="bold")

plt.sca(ax[1])
plot_grid(X_train[ind][1], curr_loc)
ax[1].set_title("Known Obstacles", fontsize=10, fontweight="bold")



plt.sca(ax[2])
plot_grid(y_train[ind][0], curr_loc)
ax[2].set_title("Target Heatmap", fontsize=10, fontweight="bold")


plt.sca(ax[3])
plot_grid(X_train[ind][2], curr_loc)
ax[3].set_title("Unseen Map", fontsize=10, fontweight="bold")


plt.tight_layout()
plt.show()
# Out:
# /var/folders/d1/h1k1jc2n6_91bpddcj351c9c0000gq/T/ipykernel_22719/3008858257.py:6: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   curr_loc = np.unravel_index(curr_loc_idx, X_train[ind][1].shape)

# %%
from data_generator import augment_data
X_train_aug, y_train_aug = augment_data(X_train, y_train)
X_test_aug, y_test_aug = augment_data(X_test, y_test)

# Shuffle training data
perm = torch.randperm(X_train_aug.size(0))
X_train_aug = X_train_aug[perm]
y_train_aug = y_train_aug[perm]
# Shuffle test data

perm = torch.randperm(X_test_aug.size(0))
X_test_aug = X_test_aug[perm]
y_test_aug = y_test_aug[perm]

print("Augmented training data shapes:", X_train_aug.shape, y_train_aug.shape)
print("Augmented test data shapes:", X_test_aug.shape, y_test_aug.shape)
# Out:
# Augmented training data shapes: torch.Size([1196688, 3, 16, 16]) torch.Size([1196688, 1, 16, 16])
# Augmented test data shapes: torch.Size([115504, 3, 16, 16]) torch.Size([115504, 1, 16, 16])

# %%
model = FlowMatchingUNet(context_channels=3, path_channels=1, out_channels=1, grid_size = 16)

dummy_input = torch.randn(1, 3, 16, 16)
dummy_noisy_path = torch.randn(1, 1, 16, 16)
dummy_t = torch.randn(1)  # Assuming time embedding dimension is 128
output = model(dummy_input, dummy_noisy_path, dummy_t)
print(f"Input shape: {dummy_input.shape}")
print(f"Output shape: {output.shape}")
# Out:
# Input shape: torch.Size([1, 3, 16, 16])
# Output shape: torch.Size([1, 1, 16, 16])

# %%
from trainer import train_flow_matching_unet

model = FlowMatchingUNet(context_channels=3, path_channels=1, out_channels=1, grid_size=16)
trained_model, train_losses, val_losses = train_flow_matching_unet(X_train_aug, y_train_aug, X_test_aug, y_test_aug, model, device=DEVICE, num_epochs=6, batch_size=64, lr=1e-3)
# Out:
# Training Flow Matching U-Net on: mps
# Pre-computing fixed validation noise and time...
# Epoch 1/6: 100%|██████████| 37397/37397 [17:01<00:00, 36.61it/s]
# Epoch [1/6] LR: 0.000987 | Train Loss: 0.0253 | EMA Val Loss: 0.0118
# Saved new best EMA model at epoch 1
# Epoch 2/6: 100%|██████████| 37397/37397 [17:18<00:00, 36.02it/s]
# Epoch [2/6] LR: 0.000843 | Train Loss: 0.0125 | EMA Val Loss: 0.0105
# Saved new best EMA model at epoch 2
# Epoch 3/6: 100%|██████████| 37397/37397 [21:29<00:00, 29.00it/s]
# Epoch [3/6] LR: 0.000587 | Train Loss: 0.0110 | EMA Val Loss: 0.0099
# Saved new best EMA model at epoch 3
# Epoch 4/6: 100%|██████████| 37397/37397 [32:48<00:00, 18.99it/s]
# Epoch [4/6] LR: 0.000302 | Train Loss: 0.0099 | EMA Val Loss: 0.0094
# Saved new best EMA model at epoch 4
# Epoch 5/6: 100%|██████████| 37397/37397 [31:58<00:00, 19.50it/s]
# Epoch [5/6] LR: 0.000082 | Train Loss: 0.0091 | EMA Val Loss: 0.0092
# Saved new best EMA model at epoch 5
# Epoch 6/6: 100%|██████████| 37397/37397 [32:50<00:00, 18.98it/s]
# Epoch [6/6] LR: 0.000000 | Train Loss: 0.0087 | EMA Val Loss: 0.0091
# Saved new best EMA model at epoch 6
# Training Complete.

# %%
plt.figure(figsize=(10, 5))
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epoch') 
plt.ylabel('MSE Loss')
plt.title('Training and Validation Loss Curves')
plt.legend()
plt.grid()
plt.show()

# %%
trained_model.to("cpu")  # Move to CPU before saving for broader compatibility
torch.save(trained_model.state_dict(), f"model_grazing_flow_matching_16x16_los_{LOS}_vision_{VISION_RADIUS}_ResAttARUnet_batch32_lr1e3_11.pth")
trained_model.to(DEVICE)
# Out:
# FlowMatchingUNet(
#   (time_mlp): Sequential(
#     (0): SinusoidalPositionEmbeddings()
#     (1): Linear(in_features=128, out_features=128, bias=True)
#     (2): SiLU()
#     (3): Linear(in_features=128, out_features=128, bias=True)
#   )
#   (inc): ResidualConvWithTime(
#     (norm1): GroupNorm(6, 6, eps=1e-05, affine=True)
#     (conv1): Conv2d(6, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(8, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (dropout): Dropout2d(p=0.0, inplace=False)
#     (time_mlp): Sequential(
#       (0): SiLU()
#       (1): Linear(in_features=128, out_features=128, bias=True)
#     )
#     (shortcut): Conv2d(6, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (down1): Down(
#     (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (block): ResidualConvWithTime(
#       (norm1): GroupNorm(8, 64, eps=1e-05, affine=True)
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (norm2): GroupNorm(8, 128, eps=1e-05, affine=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (dropout): Dropout2d(p=0.0, inplace=False)
#       (time_mlp): Sequential(
#         (0): SiLU()
#         (1): Linear(in_features=128, out_features=256, bias=True)
#       )
#       (shortcut): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#   )
#   (down2): Down(
#     (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (block): ResidualConvWithTime(
#       (norm1): GroupNorm(8, 128, eps=1e-05, affine=True)
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (norm2): GroupNorm(8, 256, eps=1e-05, affine=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (dropout): Dropout2d(p=0.0, inplace=False)
#       (time_mlp): Sequential(
#         (0): SiLU()
#         (1): Linear(in_features=128, out_features=512, bias=True)
#       )
#       (shortcut): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#   )
#   (up2): ConvTranspose2d(256, 128, kernel_size=(2, 2), stride=(2, 2))
#   (att2): AttentionBlock_GN(
#     (W_g): Sequential(
#       (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): GroupNorm(8, 64, eps=1e-05, affine=True)
#     )
#     (W_x): Sequential(
#       (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): GroupNorm(8, 64, eps=1e-05, affine=True)
#     )
#     (psi): Sequential(
#       (0): Conv2d(64, 1, kernel_size=(1, 1), stride=(1, 1))
#       (1): Sigmoid()
#     )
#     (relu): ReLU(inplace=True)
#   )
#   (conv2): ResidualConvWithTime(
#     (norm1): GroupNorm(8, 256, eps=1e-05, affine=True)
#     (conv1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(8, 128, eps=1e-05, affine=True)
#     (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (dropout): Dropout2d(p=0.0, inplace=False)
#     (time_mlp): Sequential(
#       (0): SiLU()
#       (1): Linear(in_features=128, out_features=256, bias=True)
#     )
#     (shortcut): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (up1): ConvTranspose2d(128, 64, kernel_size=(2, 2), stride=(2, 2))
#   (att1): AttentionBlock_GN(
#     (W_g): Sequential(
#       (0): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): GroupNorm(8, 32, eps=1e-05, affine=True)
#     )
#     (W_x): Sequential(
#       (0): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): GroupNorm(8, 32, eps=1e-05, affine=True)
#     )
#     (psi): Sequential(
#       (0): Conv2d(32, 1, kernel_size=(1, 1), stride=(1, 1))
#       (1): Sigmoid()
#     )
#     (relu): ReLU(inplace=True)
#   )
#   (conv1): ResidualConvWithTime(
#     (norm1): GroupNorm(8, 128, eps=1e-05, affine=True)
#     (conv1): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(8, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (dropout): Dropout2d(p=0.0, inplace=False)
#     (time_mlp): Sequential(
#       (0): SiLU()
#       (1): Linear(in_features=128, out_features=128, bias=True)
#     )
#     (shortcut): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (outc): Conv2d(64, 1, kernel_size=(1, 1), stride=(1, 1))
# )

# %%
trained_model = FlowMatchingUNet(context_channels=3, path_channels=1, out_channels=1, grid_size=16)
#LAst good : model_grazing_flow_matching_16x16_los_square360_vision_8_ResAttARUnet_batch64_lr1e3_6
#LAst good : model_grazing_flow_matching_16x16_los_square360_vision_8_ResAttARUnet_batch64_lr1e3_16
#LAst good : model_grazing_flow_matching_16x16_los_square360_vision_8_ResAttARUnet_batch64_lr1e3_18
#Last Good : model_grazing_flow_matching_16x16_los_square360_vision_8_ResAttARUnet_batch64_lr1e3_21
#Last Good : model_grazing_flow_matching_16x16_los_square360_vision_8_ResAttARUnet_batch64_lr1e3_22. (Latest dataset)
#Last Good: model_grazing_flow_matching_16x16_los_bresenham_vision_8_ResAttARUnet_batch64_lr1e3_4 (2500 dataset)
#Last Good: model_grazing_flow_matching_16x16_los_bresenham_vision_8_ResAttARUnet_batch64_lr1e3_6 (3500 dataset,  discounted step = 10, breseham
#Last Good: model_grazing_flow_matching_16x16_los_bresenham_vision_8_ResAttARUnet_batch64_lr1e3_8 (3500 dataset, discounted step = 8, breseham)
#Last Good: model_grazing_flow_matching_16x16_los_bresenham_vision_8_ResAttARUnet_batch64_lr1e3_9 (3500 dataset, discounted step = 6, breseham)
#Last Good: model_grazing_flow_matching_16x16_los_bresenham_vision_8_ResAttARUnet_batch64_lr1e3_10 (5000 dataset, discounted step = 8, bresehamm, bs = 64)



model_state_dict = torch.load("model_grazing_flow_matching_16x16_los_bresenham_vision_8_ResAttARUnet_batch64_lr1e3_10.pth")
trained_model.load_state_dict(model_state_dict)
trained_model.to(DEVICE)
# Out:
# FlowMatchingUNet(
#   (time_mlp): Sequential(
#     (0): SinusoidalPositionEmbeddings()
#     (1): Linear(in_features=128, out_features=128, bias=True)
#     (2): SiLU()
#     (3): Linear(in_features=128, out_features=128, bias=True)
#   )
#   (inc): ResidualConvWithTime(
#     (norm1): GroupNorm(6, 6, eps=1e-05, affine=True)
#     (conv1): Conv2d(6, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(8, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (dropout): Dropout2d(p=0.0, inplace=False)
#     (time_mlp): Sequential(
#       (0): SiLU()
#       (1): Linear(in_features=128, out_features=128, bias=True)
#     )
#     (shortcut): Conv2d(6, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (down1): Down(
#     (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (block): ResidualConvWithTime(
#       (norm1): GroupNorm(8, 64, eps=1e-05, affine=True)
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (norm2): GroupNorm(8, 128, eps=1e-05, affine=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (dropout): Dropout2d(p=0.0, inplace=False)
#       (time_mlp): Sequential(
#         (0): SiLU()
#         (1): Linear(in_features=128, out_features=256, bias=True)
#       )
#       (shortcut): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#   )
#   (down2): Down(
#     (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (block): ResidualConvWithTime(
#       (norm1): GroupNorm(8, 128, eps=1e-05, affine=True)
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (norm2): GroupNorm(8, 256, eps=1e-05, affine=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (dropout): Dropout2d(p=0.0, inplace=False)
#       (time_mlp): Sequential(
#         (0): SiLU()
#         (1): Linear(in_features=128, out_features=512, bias=True)
#       )
#       (shortcut): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#   )
#   (up2): ConvTranspose2d(256, 128, kernel_size=(2, 2), stride=(2, 2))
#   (att2): AttentionBlock_GN(
#     (W_g): Sequential(
#       (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): GroupNorm(8, 64, eps=1e-05, affine=True)
#     )
#     (W_x): Sequential(
#       (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): GroupNorm(8, 64, eps=1e-05, affine=True)
#     )
#     (psi): Sequential(
#       (0): Conv2d(64, 1, kernel_size=(1, 1), stride=(1, 1))
#       (1): Sigmoid()
#     )
#     (relu): ReLU(inplace=True)
#   )
#   (conv2): ResidualConvWithTime(
#     (norm1): GroupNorm(8, 256, eps=1e-05, affine=True)
#     (conv1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(8, 128, eps=1e-05, affine=True)
#     (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (dropout): Dropout2d(p=0.0, inplace=False)
#     (time_mlp): Sequential(
#       (0): SiLU()
#       (1): Linear(in_features=128, out_features=256, bias=True)
#     )
#     (shortcut): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (up1): ConvTranspose2d(128, 64, kernel_size=(2, 2), stride=(2, 2))
#   (att1): AttentionBlock_GN(
#     (W_g): Sequential(
#       (0): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): GroupNorm(8, 32, eps=1e-05, affine=True)
#     )
#     (W_x): Sequential(
#       (0): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): GroupNorm(8, 32, eps=1e-05, affine=True)
#     )
#     (psi): Sequential(
#       (0): Conv2d(32, 1, kernel_size=(1, 1), stride=(1, 1))
#       (1): Sigmoid()
#     )
#     (relu): ReLU(inplace=True)
#   )
#   (conv1): ResidualConvWithTime(
#     (norm1): GroupNorm(8, 128, eps=1e-05, affine=True)
#     (conv1): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (norm2): GroupNorm(8, 64, eps=1e-05, affine=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (dropout): Dropout2d(p=0.0, inplace=False)
#     (time_mlp): Sequential(
#       (0): SiLU()
#       (1): Linear(in_features=128, out_features=128, bias=True)
#     )
#     (shortcut): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (outc): Conv2d(64, 1, kernel_size=(1, 1), stride=(1, 1))
# )

# %%
MODEL_RUN = 8
ind = 124

context = X_test_aug[ind:ind+1].to(DEVICE)                  
context_batch = context.repeat(MODEL_RUN, 1, 1, 1)    

samples = generate_flow_heatmap(trained_model, context_batch, inference_steps=20, cfg_scale=1.0, device=DEVICE)
averaged = samples.mean(dim=0, keepdim=True) 
averaged = (averaged - averaged.min()) / (averaged.max() - averaged.min() + 1e-8)  # Normalize to [0, 1]
print(averaged.shape)      

plot_output_tensor(averaged)

# %%
plot_output_tensor(y_test_aug[ind])

# %%
def get_accuracy_on_test_set(model, X_test, y_test, device=DEVICE):
    model.eval()
    total_samples = X_test.size(0)
    correct_predictions = 0

    accuracy_dict = {}
    with torch.no_grad():
        for i in tqdm(range(total_samples)):
            context = X_test[i:i+1].to(device)
            unseen_count = context[0][2].sum().item()
            true_heatmap = y_test[i:i+1].to(device)

            # Generate predicted heatmap
            MODEL_RUN = 16
            context_batch = context.repeat(MODEL_RUN, 1, 1, 1)    

            predicted_heatmap = generate_flow_heatmap(model, context_batch, inference_steps=20, cfg_scale=1.0, device=device).mean(dim=0, keepdim=True) 

            # curr_pos = context[0][1].argmax(axis=None)
            gt_brightest_pos = true_heatmap[0][0].argmax(axis=None)
            pred_brightest_pos = predicted_heatmap[0][0].argmax(axis=None)

            correct_predictions += (gt_brightest_pos == pred_brightest_pos).item()
            key = unseen_count // 10
            if key not in accuracy_dict:
                accuracy_dict[key] = {"correct": 0, "total": 0}
            accuracy_dict[key]["correct"] += (gt_brightest_pos == pred_brightest_pos).item()
            accuracy_dict[key]["total"] += 1

    accuracy = correct_predictions / total_samples
    return accuracy, accuracy_dict

acc, acc_dict = get_accuracy_on_test_set(trained_model, X_test[:5000], y_test[:5000], device=DEVICE)
print(f"Overall Accuracy on Test Set: {acc:.4f}")
# Out:
# 100%|██████████| 5000/5000 [07:40<00:00, 10.87it/s]
# Overall Accuracy on Test Set: 0.7974

# %%
for k in sorted(acc_dict):
    correct = acc_dict[k]["correct"]
    total = acc_dict[k]["total"]
    accuracy = correct / total if total > 0 else 0
    print(f"Unseen Cells: {k*10}-{(k+1)*10 - 1}, Accuracy: {accuracy:.4f} ({correct}/{total})")
# Out:
# Unseen Cells: 0.0-9.0, Accuracy: 0.5000 (1/2)
# Unseen Cells: 10.0-19.0, Accuracy: 0.9322 (55/59)
# Unseen Cells: 20.0-29.0, Accuracy: 0.8947 (153/171)
# Unseen Cells: 30.0-39.0, Accuracy: 0.8586 (255/297)
# Unseen Cells: 40.0-49.0, Accuracy: 0.8731 (344/394)
# Unseen Cells: 50.0-59.0, Accuracy: 0.8139 (411/505)
# Unseen Cells: 60.0-69.0, Accuracy: 0.8401 (373/444)
# Unseen Cells: 70.0-79.0, Accuracy: 0.7424 (343/462)
# Unseen Cells: 80.0-89.0, Accuracy: 0.7836 (268/342)
# Unseen Cells: 90.0-99.0, Accuracy: 0.8041 (275/342)
# Unseen Cells: 100.0-109.0, Accuracy: 0.7347 (252/343)
# Unseen Cells: 110.0-119.0, Accuracy: 0.7623 (202/265)
# Unseen Cells: 120.0-129.0, Accuracy: 0.7421 (164/221)
# Unseen Cells: 130.0-139.0, Accuracy: 0.7635 (155/203)
# Unseen Cells: 140.0-149.0, Accuracy: 0.7568 (140/185)
# Unseen Cells: 150.0-159.0, Accuracy: 0.7375 (118/160)
# Unseen Cells: 160.0-169.0, Accuracy: 0.7759 (90/116)
# Unseen Cells: 170.0-179.0, Accuracy: 0.8142 (92/113)
# Unseen Cells: 180.0-189.0, Accuracy: 0.8229 (79/96)
# Unseen Cells: 190.0-199.0, Accuracy: 0.7830 (83/106)
# Unseen Cells: 200.0-209.0, Accuracy: 0.7424 (49/66)
# Unseen Cells: 210.0-219.0, Accuracy: 0.7742 (48/62)
# Unseen Cells: 220.0-229.0, Accuracy: 0.7308 (19/26)
# Unseen Cells: 230.0-239.0, Accuracy: 0.8889 (16/18)
# Unseen Cells: 240.0-249.0, Accuracy: 1.0000 (2/2)

# %%
## Testing

# %% [markdown]
# ## Testing

# %%
from inference import *

ARIADNE_SETUP = 0
TARE_SETUP = 0

# %%
from pathlib import Path
import sys
import importlib

project_root = Path.cwd().parent
sys.path.insert(0, str(project_root / "ARiADNE"))
sys.path.insert(0, str(project_root))

if ARIADNE_SETUP:
    import ARiADNE.infer as ariadne_infer_grid
    # importlib.reload(ARiADNE.infer_grid)

# %%
gen = WRPDataGenerator(16, 16)
# grid, start = gen.generate_simple_polygon_grid()
grid, start = gen.generate_valid_grid(density=5, clutter_proba=0.5, free_ratio_threshold=0.5)


# start = (0, 0)  # Starting at the top-left corner
plot_grid(grid, start)  # Plot the grid from the first channel of the input

# %%
path_greedy2, data_ = pred_path_greedy_online_flow(trained_model, grid, start, los_type=LOS, vision_radius=VISION_RADIUS, device=DEVICE, stop_at_offline_compare=False)
# plt.sca(axes[0, 0])
plot_path(grid, path_greedy2)
# Out:
# Few frontiers (1) left at step 34 and pos (12, 5). Triggering A* Escape.
# New fog revealed! Breaking escape to replan.
# Escape successful! New position: (7, 0). Continuing exploration.
# Success! Entire polygon explored in 44 steps.

# %%
path_greedy, data_ = pred_path_greedy_online_flow(trained_model, grid, start, los_type=LOS, vision_radius=VISION_RADIUS, device=DEVICE, stop_at_offline_compare=True)
# plt.sca(axes[0, 0])
plot_path(grid, path_greedy)
# Out:
# Success! Entire grid explored optimally in 32 steps.

# %%
fig, axes = plt.subplots(2, 2, figsize=(7, 7))



# Algorithm 2: 
path_astar1 = receding_horizon_astar_online(trained_model, grid, start, los_type=LOS, vision_radius=VISION_RADIUS, device=DEVICE)
plt.sca(axes[1, 0])
plot_path(grid, path_astar1)
axes[1, 0].set_title(f'FLEX+H (Path: {len(path_astar1)}) \nOnline Termination', fontsize=10, fontweight='bold')

# Algorithm 3:
path_astar2 = receding_horizon_astar_online(trained_model, grid, start, los_type=LOS, vision_radius=VISION_RADIUS, device=DEVICE, stop_at_offline_compare=True)
plt.sca(axes[0, 1])
plot_path(grid, path_astar2)
axes[0, 1].set_title(f'FLEX+H (Path: {len(path_astar2)})\n(Guided Heuristic Planner)', fontsize=10, fontweight='bold')

# Algorithm 1: Greedy Online
path_greedy, data_ = pred_path_greedy_online_flow(trained_model, grid, start, los_type=LOS, vision_radius=VISION_RADIUS, device=DEVICE, stop_at_offline_compare=True)
plt.sca(axes[0, 0])
plot_path(grid, path_greedy)
axes[0, 0].set_title(f'Model FLEX (Path: {len(path_greedy)})\n(Greedy Planner)', fontsize=10, fontweight='bold')

# Algorithm 4: HIPPS
path_hipps = neasrest_frontier_algorithm(grid, start, los_type=LOS, vision_radius=VISION_RADIUS
                                         )
plt.sca(axes[1, 1])
plot_path(grid, path_hipps)
axes[1, 1].set_title(f'Frontier Based Heuristic (Path: {len(path_hipps)})', fontsize=10, fontweight='bold')



plt.tight_layout()
plt.show()
# Out:
# Success! Entire polygon explored in 66 steps.
# Success! Entire grid explored optimally in 66 steps.
# Loop detected at step 20 and pos (4, 7)! Triggering A* Escape.
# New fog revealed! Breaking escape to replan.
# Escape successful! New position: (5, 7). Continuing exploration.
# Loop detected at step 58 and pos (10, 15)! Triggering A* Escape.
# New fog revealed! Breaking escape to replan.
# Escape successful! New position: (4, 12). Continuing exploration.
# Success! Entire grid explored optimally in 61 steps.
# Success! Entire polygon explored in 71 steps.

# %%
if ARIADNE_SETUP:
    metrics, path_ariadne = ariadne_infer_grid.run_inference(grid=grid, start=start, device="cpu", model_path='../ARiADNE/model/ae_clean/ariadne_checkpoint_td51_step_11000.pth')
    print(metrics)

    plot_path(grid, [(y, x) for x, y in path_ariadne])
    # plt.title(f'ARiADNE (Path: {round(metrics["travel_dist"], 1)})', fontsize=10, fontweight='bold')
    print("PAth Length ARiADNE:", len(path_ariadne), "Distance:", metrics["travel_dist"])
    plt.show()
# Out:
# {'travel_dist': np.float64(70.76853768846246), 'explored_rate': np.float64(0.9940476190476191), 'success_rate': True}
# PAth Length ARiADNE: 27 Distance: 70.76853768846246

# %%
solver_opt = WRPSolverTSPJF(grid, start, los_type=LOS, vision_radius=VISION_RADIUS)
path_opt, cnt_opt = solve_wrp_tsp_jf(solver_opt)
print("Optimized Path Length:", len(path_opt))
lower_bound = len(path_opt) * 13/11
print("Lower Bound: ", lower_bound)
plot_path(grid, path_opt, start)
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[77], line 2
#       1 solver_opt = WRPSolverTSPJF(grid, start, los_type=LOS, vision_radius=VISION_RADIUS)
# ----> 2 path_opt, cnt_opt = solve_wrp_tsp_jf(solver_opt)
#       3 print("Optimized Path Length:", len(path_opt))
#       4 lower_bound = len(path_opt) * 13/11
#
# File ~/MLAI/Thesis/wrp/wrp_solver_opt.py:420, in solve_wrp_tsp_jf(wrp_grid)
#     417     continue
#     419 # Basic Node Expansion
# --> 420 for neighbor in wrp_grid.get_neighbors(current_loc):
#     421     new_g = g + 1
#     422     new_seen_mask = seen_mask | wrp_grid.los_mask_table[neighbor]
#
# File ~/MLAI/Thesis/wrp/wrp_solver_opt.py:74, in WRPSolverTSPJF.get_neighbors(self, loc)
#      71 # Even with Bresenham vision, movement is typically restricted to 4 or 8 ways.
#      72 # Defaulting to 4-way movement here. Add diagonals if your agent can move diagonally.
#      73 for dr, dc in [(0, 1), (0, -1), (1, 0), (-1, 0)]:
# ---> 74     nr, nc = r + dr, c + dc
#      75     if self.in_bounds(nr, nc) and self.grid[nr][nc] == 0:
#      76         neighbors.append((nr, nc))
#
# OverflowError: Python integer -1 out of bounds for uint8

# %%
make_path_gif(grid, path_greedy, out="exploration.gif",
              los_type=LOS, vision_radius=VISION_RADIUS)
# %matplotlib inline
plt.ion()              # restore default backend for interactive plotting
# Out:
# Saved exploration.gif with 26 frames

# %%
step = 100

def plot_output_tensor2(output_tensor):
    # output_tensor = output_tensor.squeeze(0).squeeze(0)
    plt.imshow(output_tensor, cmap='hot')
    plt.colorbar()
    plt.grid()
    plt.xticks(np.arange(-0.5, output_tensor.shape[1], 1))
    plt.yticks(np.arange(-0.5, output_tensor.shape[0], 1))
    plt.tick_params(left=False, bottom=False, labelleft=False, labelbottom=False)
    # plt.title('Model Output Heatmap')
    plt.show()

plot_visibility2(grid, path_greedy2[:step], los_type=LOS, vision_radius=VISION_RADIUS, grazing_walls=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Evaluation

# %%
gtData1 = np.load("data/wrp_gt_data_16x16_los_bresenham_vision_8_125_samples_holes.npy", allow_pickle=True).item()
gtData2 = np.load("data/wrp_gt_data_16x16_los_bresenham_vision_8_200_samples_holes.npy", allow_pickle=True).item()
# gtData3 = np.load("data/wrp_gt_data_16x16_los_bresenham_vision_8_122_samples_holes.npy", allow_pickle=True).item()


#join all into gtData
gtData = {}
for key in gtData1:
    gtData[key] = gtData1[key] + gtData2[key]  # + gtData3[key]

# %%
path_opt = gtData["path_opt"][98]
path_opt
# Out:
# array([[ 9, 11],
#        [ 9, 10],
#        [ 9,  9],
#        [ 9,  8],
#        [ 9,  7],
#        [ 9,  6],
#        [ 9,  5]], dtype=uint8)

# %%
grid, start = np.array(gtData["grid"][98]), tuple(gtData["start"][98])
# plot_grid(grid, start)
plot_path(grid, path_opt)

# %%
from data_generator import _solve_grid
def evaluate_model_on_random_grids(model, polygon_type = "simple_polygon", user_neural_search=True, num_samples=5, precomputed_gt=None, stop_at_offline_compare=False):
     model.eval()
     grid_size = (16, 16)
     gt_path_lengths = []
     pred_path_lengths = []
     pred_path_lengths_search = []
     pred_path_lengths_hipps = []
     ariadne_path_lengths = []
     # pred_path_lengths_visibility = []
     if precomputed_gt is not None:
          print("Using precomputed ground truth data for evaluation.")
          num_samples = min(num_samples, len(precomputed_gt["grid"]))
          
     print(f"Evaluating on {num_samples} samples")

     for i in tqdm(range(num_samples)):

          if precomputed_gt is None:
               gen = WRPDataGenerator(*grid_size)
               grid, start = None, None
               if polygon_type == "holes":
                    grid, start = gen.generate_valid_grid(density=5)
               elif polygon_type == "simple_polygon":
                    grid, start = gen.generate_simple_polygon_grid()

               path_opt = 257
               try:
                    path_opt, _ = run_with_timeout(_solve_grid, args=(grid, start, LOS, VISION_RADIUS), timeout=300)  # 5 minute timeout per sample
               except TimeoutError:
                    print(f"Skipping: Sample {i}: Optimization timed out. Skipping this sample.")
                    continue
          
          else:
               grid, start, path_opt = precomputed_gt["grid"][i].astype(np.int8), tuple(precomputed_gt["start"][i].astype(int)), precomputed_gt["path_opt"][i].astype(np.int8)

          path_pred_line, _ = pred_path_greedy_online_flow(model, grid, start, max_steps=256, verbose=False, los_type=LOS, vision_radius=VISION_RADIUS, stop_at_offline_compare=stop_at_offline_compare, device=DEVICE)
          if (user_neural_search):
               path_pred_line_search = receding_horizon_astar_online(model, grid, start, verbose=False ,los_type=LOS, vision_radius=VISION_RADIUS, stop_at_offline_compare=stop_at_offline_compare, device=DEVICE)
          hipps_pred_line = neasrest_frontier_algorithm(grid, start, verbose=False, los_type=LOS, vision_radius=VISION_RADIUS, stop_at_offline_compare=stop_at_offline_compare)
          if ARIADNE_SETUP:
               ariadne_pred, path_ariadne = ariadne_infer_grid.run_inference(grid=grid, start=start, device="cpu", model_path='../ARiADNE/model/ae_clean/ariadne_checkpoint_td51_step_11000.pth')
          else:
               ariadne_pred = {"travel_dist": 0}

          

          if (len(path_opt) > len(path_pred_line) or len(path_opt) > len(hipps_pred_line) or len(path_opt) > len(path_pred_line_search)):
               print(f"DISCREPANCY Sample {i}: Predicted: {len(path_pred_line)}, Optimal: {len(path_opt)}")
          else:
               gt_path_lengths.append(len(path_opt))
               pred_path_lengths.append(len(path_pred_line))
               pred_path_lengths_hipps.append(len(hipps_pred_line))
               ariadne_path_lengths.append(int(ariadne_pred['travel_dist']))
               if user_neural_search: 
                    pred_path_lengths_search.append(len(path_pred_line_search))

     rmse = np.sqrt(np.mean([(gt - pred) ** 2 for gt, pred in zip(gt_path_lengths, pred_path_lengths)]))
     print(f"\nAverage Ground Truth Path Length: {np.mean(gt_path_lengths):.2f}")
     print(f"Average Predicted Path Length: {np.mean(pred_path_lengths):.2f}")
     print(f"Root Mean Squared Error in Path Lengths: {rmse:.2f}") 

     print("Ground Truth Path Length:  ", gt_path_lengths)
     print("Model Predict Path Length: ", pred_path_lengths)
     print("Nearest Frontier Predict Path Length: ", pred_path_lengths_hipps)
     print("ARiADNE Predict Path Length: ", ariadne_path_lengths)
     # print("Visibility Predict Path Length: ", pred_path_lengths_visibility)
     if user_neural_search:
          print("Neural Search Path Length: ", pred_path_lengths_search)
          return np.array(gt_path_lengths), np.array(pred_path_lengths), np.array(pred_path_lengths_search), np.array(pred_path_lengths_hipps), np.array(ariadne_path_lengths)
     else:
          return np.array(gt_path_lengths), np.array(pred_path_lengths), None , np.array(pred_path_lengths_hipps), np.array(ariadne_path_lengths)

# %%
gt_path_lengths, pred_path_lengths, pred_path_lengths_search, pred_path_lengths_hipps, ariadne_path_lengths = evaluate_model_on_random_grids(trained_model, polygon_type="holes", num_samples=300, precomputed_gt=gtData, stop_at_offline_compare=True)

# %%
if TARE_SETUP:
    import pandas as pd
    tare_res = pd.read_csv("data/results_tare_16x16_vis8_323_grids.csv")
    tare_res
    tare_path_lengths = np.array(tare_res["TARE_Dist"][:300])
    # tare_path_lengths
# if DARE_SETUP:
#     import pandas as pd
#     dare_res = pd.read_csv("data/results_dare_16_vis8_300.csv")
#     dare_path_lengths = np.array(dare_res["Travel_Distance"][:300])

#     gt_dare_res = pd.read_csv("data/result_dare_gt_16_vis8_300.csv")
#     gt_dare_path_lengths = np.array(gt_dare_res["Travel_Distance"][:300])

# %%
# (gt_dare_res["Explored_Rate"] < 0.98).sum()
# Out:
# np.int64(3)

# %%
print("Mean GT PAth Length: ", np.mean(gt_path_lengths), f" std = {np.std(gt_path_lengths)}")
print("Mean Frontier Search Path Length: ", np.mean(pred_path_lengths_hipps[pred_path_lengths_hipps<75]), f" std = {np.std(pred_path_lengths_hipps[pred_path_lengths_hipps<75])}")
if TARE_SETUP:
    print("Mean TARE Path Length: ", np.mean(tare_path_lengths[tare_path_lengths<75]), f" std = {np.std(tare_path_lengths[tare_path_lengths<75])}")
if ARIADNE_SETUP:
    print("Mean ARiADNE Path Length: ", np.mean(ariadne_path_lengths[ariadne_path_lengths<75]), f" std = {np.std(ariadne_path_lengths[ariadne_path_lengths<75])}")
# if DARE_SETUP:
#     print("Mean DARE Path Length: ", np.mean(dare_path_lengths[dare_path_lengths<75]), f" std = {np.std(dare_path_lengths[dare_path_lengths<75])}")
#     print("Mean GT DARE Path Length: ", np.mean(gt_dare_path_lengths[gt_dare_path_lengths<75]), f" std = {np.std(gt_dare_path_lengths[gt_dare_path_lengths<75])}")
print("Mean Model Path Length: ", np.mean(pred_path_lengths[pred_path_lengths<75]), f" std = {np.std(pred_path_lengths[pred_path_lengths<75])}")
print("Mean Search Path Length: ", np.mean(pred_path_lengths_search[pred_path_lengths_search<75]), f" std = {np.std(pred_path_lengths_search[pred_path_lengths_search<75])}")
# Out:
# Mean GT PAth Length:  22.22  std = 10.207755221725622
# Mean Frontier Search Path Length:  30.384615384615383  std = 12.545938226740747
# Mean TARE Path Length:  29.293478260869566  std = 13.74279228327221
# Mean ARiADNE Path Length:  29.09540636042403  std = 15.648120946165559
# Mean DARE Path Length:  31.2139446366782  std = 14.854133639157327
# Mean GT DARE Path Length:  27.805416891891888  std = 13.398975208990185
# Mean Model Path Length:  28.700680272108844  std = 16.137552843666473
# Mean Search Path Length:  27.956375838926174  std = 13.533259165625255

# %%
ARIADNE_SETUP = 1
TARE_SETUP = 1
DARE_SETUP = 1

# %%
import numpy as np
import matplotlib.pyplot as plt

# ---------------------- Prepare data ----------------------

# Compute differences and ratios
path_len_diff_model = pred_path_lengths - gt_path_lengths
path_len_ratio_model = pred_path_lengths / gt_path_lengths

path_len_diff_search = pred_path_lengths_search - gt_path_lengths
path_len_ratio_search = pred_path_lengths_search / gt_path_lengths

path_len_diff_hipps = pred_path_lengths_hipps - gt_path_lengths
path_len_ratio_hipps = pred_path_lengths_hipps / gt_path_lengths

if ARIADNE_SETUP:
    ariadne_path_lengths_ = np.array([x if x < 75 else 75 for x in ariadne_path_lengths])

    path_len_diff_ariadne = ariadne_path_lengths_ - gt_path_lengths
    path_len_ratio_ariadne = ariadne_path_lengths_ / gt_path_lengths
if TARE_SETUP:
    tare_path_lengths_ = np.array([x if x < 75 else 75 for x in tare_path_lengths])

    path_len_diff_tare = tare_path_lengths_ - gt_path_lengths
    path_len_ratio_tare = tare_path_lengths_ / gt_path_lengths



# Font sizes
TITLE_SIZE = 15
LABEL_SIZE = 16
TICK_SIZE = 16
LEGEND_SIZE = 16



# Plot settings
step = 0.25

fig, axes = plt.subplots(1, 5, figsize=(22, 4))

# Plot 1
plot_percentage_hist(axes[0], path_len_ratio_hipps, step, "Nearest Frontier", title_size=TITLE_SIZE, label_size=LABEL_SIZE, tick_size=TICK_SIZE, legend_size=LEGEND_SIZE)

# Need to normalize ratios for TARE and ARiADNE becasue they do not explore 100% grid. So sometimes they give results shorter than optimal.
# So they are combined into a single bin for the histogram. This is done in the data preparation step above.
if TARE_SETUP:
    plot_percentage_hist(axes[1], path_len_ratio_tare, step, "TARE", ratio_norm=True, title_size=TITLE_SIZE, label_size=LABEL_SIZE, tick_size=TICK_SIZE, legend_size=LEGEND_SIZE)
if ARIADNE_SETUP:
    plot_percentage_hist(axes[2], path_len_ratio_ariadne, step, "ARiADNE", ratio_norm=True, title_size=TITLE_SIZE, label_size=LABEL_SIZE, tick_size=TICK_SIZE, legend_size=LEGEND_SIZE)

# Plot 2
plot_percentage_hist(axes[3], path_len_ratio_model,step, "FLEX", title_size=TITLE_SIZE, label_size=LABEL_SIZE, tick_size=TICK_SIZE, legend_size=LEGEND_SIZE)


# Plot 3
plot_percentage_hist(axes[4], path_len_ratio_search, step, "FLEX+H", title_size=TITLE_SIZE, label_size=LABEL_SIZE, tick_size=TICK_SIZE, legend_size=LEGEND_SIZE)


plt.tight_layout(pad=2.0)
plt.show()

# %%
# def plot_percentage_hist2(ax, data, step,  title, color="skyblue", ratio_norm = False, title_size=15, label_size=16, tick_size=16, legend_size=16):
#     weights = np.ones_like(data, dtype=float) * 100.0 / len(data)
#     bins = np.arange(0, 3 + step, step)

#     data_ratio= [1 if x < 1 else x for x in data]

#     ax.hist(
#         data_ratio if ratio_norm else data,
#         bins=bins,
#         weights=weights,
#         edgecolor="black",
#         color=color
#     )
#     ax.set_title(title, fontsize=title_size, fontweight="bold")
#     ax.set_xlabel("Path Length Ratio", fontsize=label_size)
#     ax.set_ylabel("Percentage (%)", fontsize=label_size)
#     ax.axvline(1, color="red", linestyle="dashed", linewidth=2)

#     mean_ratio = np.mean(data)
#     ax.axvline(
#         mean_ratio,
#         color="green",
#         linestyle="dashed",
#         linewidth=2,
#         label=f"MCR: {mean_ratio:.2f}"
#     )

#     ax.set_xticks(np.arange(0, 3 + step, step))
#     ax.set_yticks(np.arange(0, 65, 10))
#     ax.tick_params(axis="x", rotation=90, labelsize=tick_size)
#     ax.tick_params(axis="y", labelsize=tick_size)
#     ax.legend(fontsize=legend_size)
#     ax.grid(alpha=0.3)



# if DARE_SETUP:
#     step = 0.25
#     dare_path_lengths_ = np.array([x if x < 100 else 100 for x in dare_path_lengths])
#     gt_dare_path_lengths_ = np.array([x if x < 100 else 100 for x in gt_dare_path_lengths])

#     path_len_diff_dare = dare_path_lengths_ - gt_dare_path_lengths_
#     path_len_ratio_dare = dare_path_lengths_ / gt_dare_path_lengths_



#     path_len_diff_model_with_dare_gt = pred_path_lengths - gt_dare_path_lengths_
#     path_len_ratio_model_with_dare_gt = pred_path_lengths / gt_dare_path_lengths_

#     path_len_diff_search_with_dare_gt = pred_path_lengths_search - gt_dare_path_lengths_
#     path_len_ratio_search_with_dare_gt = pred_path_lengths_search / gt_dare_path_lengths_


#     fig, axes = plt.subplots(1, 3, figsize=(12, 4))
#     plot_percentage_hist2(axes[0], path_len_ratio_dare, step, "DARE", ratio_norm=False, title_size=TITLE_SIZE, label_size=LABEL_SIZE, tick_size=TICK_SIZE, legend_size=LEGEND_SIZE)

#     plot_percentage_hist2(axes[1], path_len_ratio_model_with_dare_gt, step, "FLEX", ratio_norm=False, title_size=TITLE_SIZE, label_size=LABEL_SIZE, tick_size=TICK_SIZE, legend_size=LEGEND_SIZE)
#     plot_percentage_hist2(axes[2], path_len_ratio_search_with_dare_gt, step, "FLEX+H", ratio_norm=False, title_size=TITLE_SIZE, label_size=LABEL_SIZE, tick_size=TICK_SIZE, legend_size=LEGEND_SIZE)
#     plt.tight_layout(pad=2.0)
#     plt.show()

# %%
# #save results to npy
# results_dict = {
#     "gt_path_lengths": gt_path_lengths,
#     "pred_path_lengths": pred_path_lengths,
#     "pred_path_lengths_search": pred_path_lengths_search,
#     "pred_path_lengths_hipps": pred_path_lengths_hipps,
#     "ariadne_path_lengths": ariadne_path_lengths,
#     "tare_path_lengths": tare_path_lengths
# }
# np.save("evaluation_results/results_path_lengths_vis8_300.npy", results_dict)

# %%
import numpy as np
results = np.load("evaluation_results/results_path_lengths_vis8_300.npy", allow_pickle=True).item()

gt_path_lengths = results["gt_path_lengths"]
pred_path_lengths = results["pred_path_lengths"]
pred_path_lengths_search = results["pred_path_lengths_search"]
pred_path_lengths_hipps = results["pred_path_lengths_hipps"]
ariadne_path_lengths = results["ariadne_path_lengths"]
tare_path_lengths = results["tare_path_lengths"]

# %%
import numpy as np
from scipy.stats import wilcoxon
 
# ----------------------------------------------------------------------
# REPLACE these with your real per-instance ratio arrays (length = #maps).
# These must be paired: same index = same map.
# e.g. load from your eval outputs / .npy files:
#   flex_ratios = np.load("flex_r3_ratios.npy")
#   ariadne_ratios = np.load("ariadne_r3_ratios.npy")
# ----------------------------------------------------------------------
# Dummy example (Regime 3): replace with real data.
rng = np.random.default_rng(0)
flex_ratios     = 1.12 + 0.15 * rng.standard_gamma(2, size=300) / 2
ariadne_ratios  = 1.24 + 0.18 * rng.standard_gamma(2, size=300) / 2
 
 
def paired_wilcoxon(flex, baseline, name):
    flex = np.asarray(flex, float)
    baseline = np.asarray(baseline, float)
    assert flex.shape == baseline.shape, "arrays must be paired (same length/order)"
 
    # One-sided: is FLEX LESS than the baseline? (lower ratio = better)
    # alternative='less' tests H1: median(flex - baseline) < 0
    stat, p = wilcoxon(flex, baseline, alternative="less")
 
    med_diff = np.median(flex - baseline)
    mean_flex, mean_base = flex.mean(), baseline.mean()
    n_flex_better = int(np.sum(flex < baseline))
 
    print(f"\nFLEX vs {name}  (n={len(flex)} paired maps)")
    print(f"  mean ratio:      FLEX {mean_flex:.3f}  |  {name} {mean_base:.3f}")
    print(f"  median(FLEX-base): {med_diff:+.3f}")
    print(f"  FLEX better on:  {n_flex_better}/{len(flex)} maps "
          f"({100*n_flex_better/len(flex):.0f}%)")
    print(f"  Wilcoxon (one-sided, FLEX<base): W={stat:.1f}, p={p:.2e}")
    print(f"  -> {'SIGNIFICANT' if p < 0.05 else 'not significant'} at alpha=0.05")
    return p

# %%
paired_wilcoxon(path_len_ratio_model, path_len_ratio_ariadne, "ARiADNE")

paired_wilcoxon(path_len_ratio_model, path_len_ratio_tare, "TARE")
# Out:
# FLEX vs ARiADNE  (n=300 paired maps)
#   mean ratio:      FLEX 1.306  |  ARiADNE 1.409
#   median(FLEX-base): -0.067
#   FLEX better on:  165/300 maps (55%)
#   Wilcoxon (one-sided, FLEX<base): W=15729.0, p=1.03e-03
#   -> SIGNIFICANT at alpha=0.05
#
# FLEX vs TARE  (n=300 paired maps)
#   mean ratio:      FLEX 1.306  |  TARE 1.350
#   median(FLEX-base): -0.074
#   FLEX better on:  167/300 maps (56%)
#   Wilcoxon (one-sided, FLEX<base): W=19029.0, p=1.16e-02
#   -> SIGNIFICANT at alpha=0.05
# np.float64(0.011613651507050255)
